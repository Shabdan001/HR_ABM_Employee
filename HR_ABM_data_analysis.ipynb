# %% [markdown]
# # IBM HR Analytics: Employee Attrition Analysis

# %% [markdown]
# ![Employee-Management-Meaning-Importance-Tips-Tools---More.png](data:image/png;base64,...)

# %% [markdown]
# ### Introduction

# %% [markdown]
# # Problem Statement:
# 1. The high rate of employee attrition can have significant implications for organizations, leading to increased recruitment and training costs, reduced productivity, and decreased employee morale.
# 2. It is crucial for companies to understand the underlying factors contributing to attrition and take proactive measures to address them.
#
#
#
# # Project Objective:
# 1. The objective of this project is to perform an Exploratory Data Analysis (EDA) on the IBM HR Analytics Employee Attrition & Performance dataset using Python.
# 2. The goal is to gain insights into the factors influencing employee attrition and performance within the organization.
# 3. By examining various features and conducting statistical analysis, we aim to identify patterns, trends, and potential areas for improvement that can help the company better understand and manage employee attrition and performance.

# %% [markdown]
# ## Some categorical variables were already label encoded. Here are the corresponding values:
#
# Education [1]'Below College' [2] 'College' [3] 'Bachelor' [4] 'Master' [5] 'Doctor'
#
# EnvironmentSatisfaction [1] 'Low' [2] 'Medium' [3] 'High' [4] 'Very High'
#
# JobInvolvement [1] 'Low' [2] 'Medium' [3] 'High' [4] 'Very High'
#
# JobSatisfaction [1] 'Low' [2] 'Medium' [3] 'High' [4] 'Very High'
#
# PerformanceRating [1] 'Low' [2] 'Good' [3] 'Excellent' [4] 'Outstanding'
#
# RelationshipSatisfaction [1] 'Low' [2] 'Medium' [3] 'High' [4] 'Very High'
#
# WorkLifeBalance [1] 'Bad' [2] 'Good' [3] 'Better' [4] 'Best'

# %% [markdown]
# # Dataset Describe

# %% [markdown]
# 1. **Age**: Employee's age.
# 2. **Gender**: Employee's gender.
# 3. **BusinessTravel**: Frequency of employees' business trips.
# 4. **DailyRate**: Daily salary rate for employees.
# 5. **Department**: Office of employees.
# 6. **DistanceFromHome**: Distance from home to work in miles.
# 7. **EducationLevel**: Level of education achieved by staff.
# 8. **EducationField**: Employee's field of study.
# 9. **EmployeeCount**: Total number of employees in the organization.
# 10. **EmployeeNumber**: A unique identifier for each employee record.
# 11. **EnvironmentSatisfaction**: Employee satisfaction with their working environment.
# 12. **HourlyRate**: Hourly rate for employees.
# 13. **JobInvolvement**: Level of involvement required for the employee's job.
# 14. **JobLevel**: Employee's level of work.
# 15. **JobRole**: The role of employees in the organization.
# 16. **JobSatisfaction**: Employee satisfaction with their work.
# 17. **MaritalStatus**: Employee's marital status.
# 18. **MonthlyIncome**: Employee's monthly income.
# 19. **MonthlyRate**: Monthly salary rate for employees.
# 20. **NumCompaniesWorked**: Number of companies the employee worked for.
# 21. **Over18**: Whether the employee is over 18 years old.
# 22. **OverTime**: Do employees work overtime.
# 23. **PercentSalaryHike**: Salary increase rate for employees.
# 24. **PerformanceRating**: The performance rating of the employee.
# 25. **RelationshipSatisfaction**: Employee satisfaction with their relationships.
# 26. **StandardHours**: Standard working hours for employees.
# 27. **StockOptionLevel**: Employee stock option level.
# 28. **TotalWorkingYears**: Total number of years the employee has worked.
# 29. **TrainingTimesLastYear**: Number of times employees were taken to training in the last year.
# 30. **WorkLifeBalance**: Employees' perception of their work-life balance.
# 31. **YearsAtCompany**: Number of years employees have been with the company.
# 32. **YearsInCurrentRole**: Number of years the employee has been in their current role.
# 33. **YearsSinceLastPromotion**: Number of years since the employee's last promotion.
# 34. **YearsWithCurrManager**: Number of years an employee has been with their current manager.
# 35. **Attrition**: Does the employee leave the organization.

# %% [markdown]
# 1. **Age**: Возраст сотрудника.
# 2. **Gender**: Пол сотрудника.
# 3. **BusinessTravel**: Частота деловых поездок сотрудников.
# 4. **DailyRate**: Дневная ставка оплаты труда для сотрудников.
# 5. **Department**: Отдел, в котором работает сотрудник.
# 6. **DistanceFromHome**: Расстояние от дома до работы в милях.
# 7. **EducationLevel**: Уровень образования, достигнутый сотрудником.
# 8. **EducationField**: Область образования сотрудника.
# 9. **EmployeeCount**: Общее количество сотрудников в организации.
# 10. **EmployeeNumber**: Уникальный идентификатор записи о каждом сотруднике.
# 11. **EnvironmentSatisfaction**: Удовлетворенность сотрудников своим рабочим окружением.
# 12. **HourlyRate**: Почасовая ставка оплаты труда для сотрудников.
# 13. **JobInvolvement**: Уровень вовлеченности, требуемый для работы сотрудника.
# 14. **JobLevel**: Уровень работы сотрудника.
# 15. **JobRole**: Роль сотрудника в организации.
# 16. **JobSatisfaction**: Удовлетворенность сотрудников своей работой.
# 17. **MaritalStatus**: Семейное положение сотрудника.
# 18. **MonthlyIncome**: Ежемесячный доход сотрудника.
# 19. **MonthlyRate**: Ежемесячная ставка оплаты труда для сотрудников.
# 20. **NumCompaniesWorked**: Количество компаний, в которых работал сотрудник.
# 21. **Over18**: Превышает ли возраст сотрудника 18 лет.
# 22. **OverTime**: Работают ли сотрудники сверхурочно.
# 23. **PercentSalaryHike**: Уровень повышения заработной платы для сотрудников.
# 24. **PerformanceRating**: Рейтинг производительности сотрудника.
# 25. **RelationshipSatisfaction**: Удовлетворенность сотрудников своими отношениями.
# 26. **StandardHours**: Стандартное рабочее время для сотрудников.
# 27. **StockOptionLevel**: Уровень опционов на акции для сотрудника.
# 28. **TotalWorkingYears**: Общее количество лет работы сотрудника.
# 29. **TrainingTimesLastYear**: Количество раз, когда сотрудники проходили обучение в прошлом году.
# 30. **WorkLifeBalance**: Восприятие сотрудниками баланса между работой и личной жизнью.
# 31. **YearsAtCompany**: Количество лет, которое сотрудники проработали в компании.
# 32. **YearsInCurrentRole**: Количество лет, которое сотрудник провел на своей текущей должности.
# 33. **YearsSinceLastPromotion**: Количество лет с момента последнего повышения сотрудника.
# 34. **YearsWithCurrManager**: Количество лет, которое сотрудник проработал с текущим руководителем.
# 35. **Attrition**: Уходит ли сотрудник из организации.

# %% [markdown]
# # Import libraries

# %%
# Import basic libraries
import pandas as pd
import numpy as np

# library for show graphs
import matplotlib.pyplot as plt
import seaborn as sns

# library for separate to train and test split
from sklearn.model_selection import train_test_split, KFold

# library for impute missing value
from feature_engine.imputation import MeanMedianImputer, RandomSampleImputer, EndTailImputer, CategoricalImputer

# library for encode and scaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import RobustScaler, MinMaxScaler, MaxAbsScaler
from category_encoders.woe import WOEEncoder
from feature_engine.encoding import MeanEncoder

# ANN library
import tensorflow as tf
from scikeras.wrappers import KerasRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.optimizers import Adam, SGD, Nadam, RMSprop, Adadelta
from keras.callbacks import EarlyStopping
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.regularizers import l2
from tensorflow.keras import regularizers

# Callback, Checkpoint
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler


# metrics score
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, f1_score, recall_score, accuracy_score, precision_score
from sklearn.model_selection import cross_val_score, cross_val_predict

# GridSearchCV
from sklearn.model_selection import GridSearchCV

# Discretization
from feature_engine.discretisation import EqualFrequencyDiscretiser, EqualWidthDiscretiser, DecisionTreeDiscretiser

#Outliers
from feature_engine.outliers import Winsorizer

# feature selection
from feature_engine.selection import (
    DropConstantFeatures,
    DropDuplicateFeatures,
    SmartCorrelatedSelection
)

#Pipeline
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Import dataset

# %%
dataset = pd.read_csv('/Users/shabdantaalaibekov/Documents/KV_AI_JLM_7/Human_Resources_TP.csv')
dataset.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely     1102.0                   Sales
# 1   49        No  Travel_Frequently      279.0  Research & Development
# 2   37       Yes      Travel_Rarely     1373.0  Research & Development
# 3   33        No  Travel_Frequently     1392.0  Research & Development
# 4   27        No      Travel_Rarely      591.0  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0               1.0        2.0  Life Sciences            1.0             1.0
# 1               8.0        1.0  Life Sciences            1.0             2.0
# 2               2.0        2.0          Other            1.0             4.0
# 3               3.0        4.0  Life Sciences            1.0             5.0
# 4               2.0        1.0        Medical            1.0             7.0
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
dataset.columns.unique()
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### Information about employee dataset

# %%
dataset.shape
# Out:
# (1470, 35)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1462 non-null   object
#  3   DailyRate                 1455 non-null   float64
#  4   Department                1446 non-null   object
#  5   DistanceFromHome          1460 non-null   float64
#  6   Education                 1460 non-null   float64
#  7   EducationField            1451 non-null   object
#  8   EmployeeCount             1460 non-null   float64
#  9   EmployeeNumber            1458 non-null   float64
#  10  EnvironmentSatisfaction   1457 non-null   float64
#  11  Gender                    1454 non-null   object
#  12  HourlyRate                1463 non-null   float64
# ...

# %%
dataset.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1455.0    800.989691   403.300488   102.0   465.00
# DistanceFromHome          1460.0      9.182192     8.098754     1.0     2.00
# Education                 1460.0      2.913699     1.025088     1.0     2.00
# EmployeeCount             1460.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1458.0   1029.981481   600.366246     1.0   498.25
# EnvironmentSatisfaction   1457.0      2.720659     1.092340     1.0     2.00
# HourlyRate                1463.0     65.897471    20.357419    30.0    48.00
# JobInvolvement            1456.0      2.729396     0.712858     1.0     2.00
# JobLevel                  1457.0      2.062457     1.106088     1.0     1.00
# JobSatisfaction           1457.0      2.728209     1.101438     1.0     2.00
# ...

# %% [markdown]
# ### Show Missing Values in sum

# %%
# All variables have missing values except for AGE and ATTRITION
dataset.isnull().sum()
# Out:
# Age                          0
# Attrition                    0
# BusinessTravel               8
# DailyRate                   15
# Department                  24
# DistanceFromHome            10
# Education                   10
# EducationField              19
# EmployeeCount               10
# EmployeeNumber              12
# EnvironmentSatisfaction     13
# Gender                      16
# HourlyRate                   7
# JobInvolvement              14
# JobLevel                    13
# JobRole                     30
# JobSatisfaction             13
# MaritalStatus               21
# MonthlyIncome               27
# MonthlyRate                 22
# NumCompaniesWorked           8
# Over18                      11
# OverTime                    21
# PercentSalaryHike           10
# PerformanceRating           15
# RelationshipSatisfaction    10
# StandardHours               11
# StockOptionLevel            12
# TotalWorkingYears           21
# TrainingTimesLastYear       12
# ...

# %% [markdown]
# ### Show missing values with Histogram

# %%
sns.heatmap(dataset.isnull(), yticklabels = False, cbar = False, cmap = 'Blues')
# Out:
# <Axes: >

# %% [markdown]
# ### Show distribution of dataset

# %%
# The graph shows that the data is not evenly distributed
dataset.hist(bins = 30, figsize = (25, 15), color = 'blue')
plt.show()

# %% [markdown]
# ### Histogram of who left the firm and did not leave

# %%
sns.set_style('darkgrid')
sns.countplot(data = dataset, x = 'Gender')
plt.show()

size = dataset.groupby('Attrition').size()
percent = size/1470
print(percent)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# dtype: float64

# %%
sns.set_style('darkgrid')
sns.countplot(data = dataset, x = 'Attrition')
plt.show()

size = dataset.groupby('Attrition').size()
percent = size/1470
print(percent)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# dtype: float64

# %%
categorical_feat = [
    var for var in dataset.columns if dataset[var].dtype == 'O' #and var != 'Attrition'
]
categorical_feat
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
# Manual encoding some categorical variables
dataset['Attrition'] = dataset['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0)
dataset['OverTime'] = dataset['OverTime'].apply(lambda x: 1 if x == 'Yes' else 0)
dataset['Over18'] = dataset['Over18'].apply(lambda x: 1 if x == 'Y' else 0)
dataset['Gender'] = dataset['Gender'].apply(lambda x: 1 if x == 'Female' else 0) # 0 Male 1 Female

# %%
print(dataset.Attrition.unique())
print(dataset.OverTime.unique())
print(dataset.Over18.unique())
print(dataset.Gender.unique())
# Out:
# [1 0]
# [1 0]
# [1 0]
# [1 0]

# %%
# Drop constant features
dataset.drop(labels = ['EmployeeCount', 'StandardHours', 'Over18', 'EmployeeNumber'], axis = 1, inplace = True)

# %%
left = dataset[dataset['Attrition'] == 1]
stayed = dataset[dataset['Attrition'] == 0]

# %%
print('Total = ', len(dataset))
print('Number of employees who left the company = ', len(left))
print('Number of employees who did not leave the company (stayed) = ', len(stayed))
# Out:
# Total =  1470
# Number of employees who left the company =  237
# Number of employees who did not leave the company (stayed) =  1233

# %% [markdown]
# #### We look at the characteristics of each variable, the VALUES are the NUMBER and PERCENTAGE

# %%
for col in dataset:
  freg_table = dataset[col].value_counts().reset_index()
  freg_table.columns = [col, 'Count']
  freg_table['Percentage'] = round((freg_table['Count'] / freg_table['Count'].sum()) * 100, 2)
  display(freg_table)
# Out:
#     Age  Count  Percentage
# 0    35     78        5.31
# 1    34     77        5.24
# 2    36     69        4.69
# 3    31     69        4.69
# 4    29     68        4.63
# 5    32     61        4.15
# 6    30     60        4.08
# 7    33     58        3.95
# 8    38     58        3.95
# 9    40     57        3.88
# 10   37     50        3.40
# 11   27     48        3.27
# 12   28     48        3.27
# 13   42     46        3.13
# 14   39     42        2.86
# 15   45     41        2.79
# 16   41     40        2.72
# 17   26     39        2.65
# 18   44     33        2.24
# 19   46     33        2.24
# 20   43     32        2.18
# 21   50     30        2.04
# 22   25     26        1.77
# 23   24     26        1.77
# 24   49     24        1.63
# 25   47     24        1.63
# 26   55     22        1.50
# 27   51     19        1.29
# 28   53     19        1.29
# 29   48     19        1.29
# 30   54     18        1.22
# 31   52     18        1.22
# 32   22     16        1.09
# ...

# %% [markdown]
# ## Correlation Matrix

# %%
corr = dataset.corr(numeric_only = True)
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### Distribution of those who left the firm by AGE

# %%
plt.figure(figsize = (15, 8))
sns.countplot(x = 'Age', hue = 'Attrition', data = dataset)
plt.title('Blue [stayed company]  Orange[left company]')
# Out:
# Text(0.5, 1.0, 'Blue [stayed company]  Orange[left company]')

# %% [markdown]
# ### Count who left and stayed in company by JobRole, MaritalStatus, JobInvolvement, JobLevel

# %%
size = dataset.groupby('MaritalStatus').size()
percent = size/1470
print(percent)
# Out:
# MaritalStatus
# Divorced    0.219728
# Married     0.451020
# Single      0.314966
# dtype: float64

# %%
plt.figure(figsize = (20, 20))
plt.subplot(411)
sns.countplot(x = 'JobRole', hue = 'Attrition', data = dataset)

plt.subplot(412)
sns.countplot(x = 'MaritalStatus', hue = 'Attrition', data = dataset)

plt.subplot(413)
sns.countplot(x = 'JobInvolvement', hue = 'Attrition', data = dataset)

plt.subplot(414)
sns.countplot(x = 'JobLevel', hue = 'Attrition', data = dataset)
# Out:
# <Axes: xlabel='JobLevel', ylabel='count'>

# %% [markdown]
# ### NOTES
# 1. The graph shows that those who left are fewer than those who stayed 83% and 16% left
# 2. In the amount of 237 left and 1233 stayed
# 3. We also looked at the characteristics of all variables in terms of quantity and percentage
# 4. Looked at the distribution of those who left and stayed by AGE variable
# 5. Looked at the number of those who left and stayed by variables JobRole
# 6. MaritalStatus, JobInvolovment, JobLevel

# %% [markdown]
# ### from next hist we can see histogram and distribution plot some variables

# %%
sns.displot(dataset['YearsAtCompany'])
plt.title('This graph shows us that in most people work from 1 to 5 years')
# Out:
# Text(0.5, 1.0, 'This graph shows us that in most people work from 1 to 5 years')

# %%
sns.displot(dataset['MonthlyIncome'])
plt.title('from this graph we can see that the average monthly income is from 2 to 5 thousand in most')
# Out:
# Text(0.5, 1.0, 'from this graph we can see that the average monthly income is from 2 to 5 thousand in most')

# %%
sns.displot(dataset['Age'])
plt.title('from this graph we can see that most of the workforce is between 30 - 40 age')
# Out:
# Text(0.5, 1.0, 'from this graph we can see that most of the workforce is between 30 - 40 age')

# %%
sns.displot(dataset['TotalWorkingYears'])
plt.title('Here we see that the largest part of the total number of working years is from 7 to 10 years')
# Out:
# Text(0.5, 1.0, 'Here we see that the largest part of the total number of working years is from 7 to 10 years')

# %%
sns.set_style('darkgrid')
sns.countplot(data=dataset, x='Gender', hue='Gender')
plt.title('In this graph, we can see the distribution of employees by gender 0-Male 1-Female')
plt.show()

size = dataset.groupby('Gender').size()
percent = size / len(dataset)
print(percent)
# Out:
# Gender
# 0    0.604082
# 1    0.395918
# dtype: float64

# %%
sns.countplot(x = 'Gender', data = dataset, hue = 'Attrition')
plt.title('The attrition rate among Males is More than Females')
# Out:
# Text(0.5, 1.0, 'The attrition rate among Males is More than Females')

# %% [markdown]
# ## NOTES
# 1. Most people work from 1 to 5 years
# 2. Most people get from 2 to 5 thousand
# 3. The main age of the labor force is 30-40 years old
# 4. Most people work for 7 to 10 years
# 5. Those who left and stayed, there are relatively more men because there are more men in the dataset
# 6. we can see that there are more men than woman

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.countplot(x = 'Gender', data = dataset, hue = 'JobSatisfaction', ax = ax)
plt.title('This graph show us distribution between Job Satisfaction and Gender')

plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
value_1 = dataset["JobSatisfaction"].value_counts()
plt.title("Employees by Job Satisfaction", fontweight="black", size=20, pad=20)
plt.pie(value_1.values, labels=value_1.index, autopct="%.1f%%",pctdistance=0.8,startangle=90,
        colors=['#FFB300', '#FFC300', '#FFD700', '#FFFF00'],textprops={"fontweight":"black","size":15})
center_circle = plt.Circle((0, 0), 0.4, fc='white')
fig = plt.gcf()
fig.gca().add_artist(center_circle)

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.countplot(x = 'Gender', data = dataset, hue = 'JobLevel', ax = ax)
plt.title('This graph show us distribution between Job Level and Gender')
# Out:
# Text(0.5, 1.0, 'This graph show us distribution between Job Level and Gender')

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.countplot(x = 'Gender', data = dataset, hue = 'Education', ax = ax)
plt.title('This graph whos us distribution between Education and Gender')
# Out:
# Text(0.5, 1.0, 'This graph whos us distribution between Education and Gender')

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.countplot(x = 'Gender', data = dataset, hue = 'TrainingTimesLastYear', ax = ax)
plt.title('This graph whos us distribution between Genser and TrainingTimesLastYear')
# Out:
# Text(0.5, 1.0, 'This graph whos us distribution between Genser and TrainingTimesLastYear')

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.countplot(x = 'Gender', data = dataset, hue = 'MaritalStatus', ax = ax)
plt.title('This graph show us Mariatl Status between Male and Female')
# Out:
# Text(0.5, 1.0, 'This graph show us Mariatl Status between Male and Female')

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.countplot(x = 'Education', data = dataset, hue = 'MaritalStatus', ax = ax)
plt.title('This graph show us Education between Marital Status')
# Out:
# Text(0.5, 1.0, 'This graph show us Education between Marital Status')

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.countplot(x = 'Education', data = dataset, hue = 'Gender', ax = ax)
plt.title('This graph show us Education between Gender')
# Out:
# Text(0.5, 1.0, 'This graph show us Education between Gender')

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.countplot(x = 'Education', data = dataset, hue = 'BusinessTravel', ax = ax)
plt.title('This graph show us distribution between Education and Business Travel')
# Out:
# Text(0.5, 1.0, 'This graph show us distribution between Education and Business Travel')

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.countplot(x = 'Education', data = dataset, hue = 'WorkLifeBalance', ax = ax)
plt.title('This graph show us distribution between Education and Work Life Balance')
plt.legend(labels = ['Bad - 1', 'Good - 2',  'Better - 3', 'Best - 4'])

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.countplot(x = 'Education', data = dataset, hue = 'RelationshipSatisfaction', ax = ax)
plt.title('Distribution between Education and Relationship Satisfaction')
# Out:
# Text(0.5, 1.0, 'Distribution between Education and Relationship Satisfaction')

# %% [markdown]
# ## NOTES
# 1. Satisfied with their work by variable gender are on average similar
# 2. Job Level and Gender are on average similar

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (12, 7))
plt.title('Here we see that in general woman get more than man')
sns.boxplot(x = 'Gender', y = 'MonthlyIncome', data = dataset, hue = 'Gender')
# Out:
# <Axes: title={'center': 'Here we see that in general woman get more than man'}, xlabel='Gender', ylabel='MonthlyIncome'>

# %%
plt.figure(figsize = (12, 7))
plt.title('Here distribution between Monthly Income and Eduaction Field')
sns.boxplot(x = 'MonthlyIncome', y = 'EducationField', data = dataset, hue = 'EducationField')
# Out:
# <Axes: title={'center': 'Here distribution between Monthly Income and Eduaction Field'}, xlabel='MonthlyIncome', ylabel='EducationField'>

# %%
plt.figure(figsize = (12, 7))
plt.title('Here distribution between Monthly Income and Job Role')
sns.boxplot(x = 'MonthlyIncome', y = 'JobRole', data = dataset, hue = 'JobRole')
# Out:
# <Axes: title={'center': 'Here distribution between Monthly Income and Job Role'}, xlabel='MonthlyIncome', ylabel='JobRole'>

# %%
plt.figure(figsize = (12, 7))
plt.title('Here distribution between Monthly Income and Marital Status')
sns.boxplot(x = 'MonthlyIncome', y = 'MaritalStatus', data = dataset, hue = 'MaritalStatus')
# Out:
# <Axes: title={'center': 'Here distribution between Monthly Income and Marital Status'}, xlabel='MonthlyIncome', ylabel='MaritalStatus'>

# %% [markdown]
# ## NOTES
# 1. Women get a little more than Man
# 2. Marketrs have the highest monthly income
# 3. Managers and Research Directors get paid more than others
# 4. Divorced people get more married and unmarried

# %%
# It can be see that AGE does not affect the MONTHLYRATE
sns.lineplot(x = 'Age', y = 'MonthlyRate', data = dataset, errorbar = None)
# Out:
# <Axes: xlabel='Age', ylabel='MonthlyRate'>

# %%
sns.barplot(x = 'Gender', y = 'EnvironmentSatisfaction', data = dataset, hue = 'Gender', errorbar = None)
# Out:
# <Axes: xlabel='Gender', ylabel='EnvironmentSatisfaction'>

# %%
# It can be see that AGE does not affect the EnvironmentSatisfaction
sns.lineplot(x = 'Age', y = 'EnvironmentSatisfaction', data = dataset, errorbar = None)
# Out:
# <Axes: xlabel='Age', ylabel='EnvironmentSatisfaction'>

# %%
dataset.Department.unique()
# Out:
# array(['Sales', 'Research & Development', nan, 'Human Resources'],
#       dtype=object)

# %%
# Relationship between Department and Attrition
sns.lineplot(x = 'Department', y = 'Attrition', data = dataset, errorbar = None)
# Out:
# <Axes: xlabel='Department', ylabel='Attrition'>

# %%
# From this graph we see that the salary increase as a percentage is affected by the variable DEPARTMENT,
# in which we see that the RESEARCH and DEVELOPMENT department has the most influence
sns.lineplot(x = 'Department', y = 'PercentSalaryHike', data = dataset, errorbar = None)
# Out:
# <Axes: xlabel='Department', ylabel='PercentSalaryHike'>

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
sns.lineplot(x = 'PerformanceRating', y = 'DistanceFromHome', data = dataset, errorbar = None)
plt.title('from this graph it can be seen that the distance from home does not affect the percentage of salary increases')
# Out:
# Text(0.5, 1.0, 'from this graph it can be seen that the distance from home does not affect the percentage of salary increases')

# %%
sns.lineplot(x = 'YearsAtCompany', y = 'PercentSalaryHike', data = dataset, errorbar = None)
plt.title('From this plot we can see that the percentage of salary hike does not depend on number of years')
# Out:
# Text(0.5, 1.0, 'From this plot we can see that the percentage of salary hike does not depend on number of years')

# %%
sns.lineplot(x = 'PerformanceRating', y = 'PercentSalaryHike', data = dataset)
plt.title('Here we can see that the percentage of hike in salary only depends upon Performance of the Employee')
# Out:
# Text(0.5, 1.0, 'Here we can see that the percentage of hike in salary only depends upon Performance of the Employee')

# %% [markdown]
# # NOTES
# 1. It can be see that AGE does not affect the MONTHLYRATE
# 2. It can be see that AGE does not affect the EnvironmentSatisfaction
# 3. From this graph we see that the salary increase as a percentage is affected by the variable DEPARTMENT, in which we see that the RESEARCH and DEVELOPMENT department has the most influence
# 4. from this graph it can be seen that the distance from home does not affect the percentage of salary increases
# 5. From this plot we can see that the percentage of salary hike does not depend on number of years
# 6. Here we can see that the percentage of hike in salary only depends upon Performance of the Employee

# %% [markdown]
# #### We divided the "Attrition" variable into those who left and stayed at the workplace, and then we look at the characteristics and graphs

# %%
# Here we will see a decricption of the characteristics of those who left
left.describe().T
# Out:
#                           count          mean          std     min     25%  \
# Age                       237.0     33.607595     9.689350    18.0    28.0
# Attrition                 237.0      1.000000     0.000000     1.0     1.0
# DailyRate                 235.0    745.851064   400.538643   103.0   399.5
# DistanceFromHome          234.0     10.645299     8.427820     1.0     3.0
# Education                 234.0      2.846154     1.011652     1.0     2.0
# EnvironmentSatisfaction   234.0      2.465812     1.168665     1.0     1.0
# Gender                    237.0      0.358650     0.480619     0.0     0.0
# HourlyRate                235.0     65.629787    20.150798    31.0    50.0
# JobInvolvement            236.0      2.516949     0.774410     1.0     2.0
# JobLevel                  234.0      1.645299     0.943830     1.0     1.0
# JobSatisfaction           236.0      2.466102     1.119895     1.0     1.0
# ...

# %%
# Here we will see a decricption of the characteristics of those who stayed
stayed.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1233.0     37.561233     8.888360    18.0    31.00
# Attrition                 1233.0      0.000000     0.000000     0.0     0.00
# DailyRate                 1220.0    811.610656   403.127621   102.0   476.25
# DistanceFromHome          1226.0      8.902936     8.007621     1.0     2.00
# Education                 1226.0      2.926591     1.027536     1.0     2.00
# EnvironmentSatisfaction   1223.0      2.769419     1.070730     1.0     2.00
# Gender                    1233.0      0.403082     0.490716     0.0     0.00
# HourlyRate                1228.0     65.948697    20.404463    30.0    48.00
# JobInvolvement            1220.0      2.770492     0.693186     1.0     2.00
# JobLevel                  1223.0      2.142273     1.117208     1.0     1.00
# JobSatisfaction           1221.0      2.778870     1.091057     1.0     2.00
# ...

# %% [markdown]
# ## LEFT

# %%
plt.figure(figsize = (12, 7))
plt.title('Here distribution between Monthly Income and Job Role who LEFT')
sns.boxplot(x = 'MonthlyIncome', y = 'JobRole', data = left, hue = 'JobRole')
# Out:
# <Axes: title={'center': 'Here distribution between Monthly Income and Job Role who LEFT'}, xlabel='MonthlyIncome', ylabel='JobRole'>

# %%
plt.figure(figsize = (12, 7))
plt.title('Here distribution between Monthly Income and Marital Status who LEFT, it is clear that married people have more monthly income than non-married and divorced people')
sns.boxplot(x = 'MonthlyIncome', y = 'MaritalStatus', data = left, hue = 'MaritalStatus')
# Out:
# <Axes: title={'center': 'Here distribution between Monthly Income and Marital Status who LEFT, it is clear that married people have more monthly income than non-married and divorced people'}, xlabel='MonthlyIncome', ylabel='MaritalStatus'>

# %%
plt.figure(figsize = (12, 7))
plt.title('Here distribution between Monthly Income and Education Field who LEFT, it is clear that those in the field of marketing earn much more')
sns.boxplot(x = 'MonthlyIncome', y = 'EducationField', data = left, hue = 'EducationField')
# Out:
# <Axes: title={'center': 'Here distribution between Monthly Income and Education Field who LEFT, it is clear that those in the field of marketing earn much more'}, xlabel='MonthlyIncome', ylabel='EducationField'>

# %% [markdown]
# ## STAYED

# %%
plt.figure(figsize = (12, 7))
plt.title('Here distribution between Monthly Income and Marital Status who STAYED'
'of those who have not left the workplace, it is clear that divorced people receive more, but not by much')
sns.boxplot(x = 'MonthlyIncome', y = 'MaritalStatus', data = stayed, hue = 'MaritalStatus')
# Out:
# <Axes: title={'center': 'Here distribution between Monthly Income and Marital Status who STAYEDof those who have not left the workplace, it is clear that divorced people receive more, but not by much'}, xlabel='MonthlyIncome', ylabel='MaritalStatus'>

# %%
plt.figure(figsize = (12, 7))
plt.title('Here distribution between Monthly Income and Job Role who STAYED')
sns.boxplot(x = 'MonthlyIncome', y = 'JobRole', data = stayed, hue = 'JobRole')
# Out:
# <Axes: title={'center': 'Here distribution between Monthly Income and Job Role who STAYED'}, xlabel='MonthlyIncome', ylabel='JobRole'>

# %%
plt.figure(figsize = (12, 7))
plt.title('Here distribution between Monthly Income and Education Field who STAYED')
sns.boxplot(x = 'MonthlyIncome', y = 'EducationField', data = stayed, hue = 'EducationField')
# Out:
# <Axes: title={'center': 'Here distribution between Monthly Income and Education Field who STAYED'}, xlabel='MonthlyIncome', ylabel='EducationField'>

# %%
plt.figure(figsize = (12, 7))
sns.kdeplot(left['YearsAtCompany'], label = 'Employee who left', fill = True, color = 'red')
sns.kdeplot(stayed['YearsAtCompany'], label = 'Employee who stayed', fill = True, color = 'blue')
plt.title('Look at the distribution of the graph by variable years in the company, those who left and thosw who stayed')
plt.legend()
plt.xlabel('Years At Company')
# Out:
# Text(0.5, 0, 'Years At Company')

# %%
plt.figure(figsize = (12, 7))
sns.kdeplot(left['PercentSalaryHike'], label = 'Employee who left', fill = True, color = 'red')
sns.kdeplot(stayed['PercentSalaryHike'], label = 'Employee who stayed', fill = True, color = 'blue')
plt.title('Look at the distribution of the graph by variable Percent Salary Hike, those who left and thosw who stayed')
plt.legend()
plt.xlabel('Percent Salary Hike')
# Out:
# Text(0.5, 0, 'Percent Salary Hike')

# %%
plt.figure(figsize = (12, 7))
sns.kdeplot(left['Education'], label = 'Employee who left', fill = True, color = 'red')
sns.kdeplot(stayed['Education'], label = 'Employee who stayed', fill = True, color = 'blue')
plt.title('Look at the distribution of the graph by variable Education, those who left and thosw who stayed')
plt.legend()
plt.xlabel('Education')
# Out:
# Text(0.5, 0, 'Education')

# %%
plt.figure(figsize = (12, 7))
sns.kdeplot(left['JobLevel'], label = 'Employee who left', fill = True, color = 'red')
sns.kdeplot(stayed['JobLevel'], label = 'Employee who stayed', fill = True, color = 'blue')
plt.title('Look at the distribution of the graph by variable Job Level, those who left and thosw who stayed')
plt.legend()
plt.xlabel('Job Level')
# Out:
# Text(0.5, 0, 'Job Level')

# %% [markdown]
# Key Insights
#
#     •	Employee Retention: Understand and address the reasons why 16% of employees leave.
#     •	Gender Pay Gap: Ensure fair pay for all employees.
#     •	Salary Increase Policies: Focus on performance-based increases.
#     •	Department Focus: Pay special attention to the research and development department.
#     •	Employee Satisfaction: Improve engagement and work environment, as age is not significant.

# %% [markdown]
# Ключевые выводы
#
# 	•	Удержание сотрудников: Нужно понять и устранить причины ухода 16% сотрудников.
# 	•	Гендерный разрыв: Обеспечить справедливую оплату труда для всех.
# 	•	Повышение зарплаты: Ориентироваться на производительность.
# 	•	Фокус на департаменты: Особое внимание департаменту исследований и разработок.
# 	•	Удовлетворенность: Влиять на вовлеченность и рабочую среду, так как возраст незначителен.
